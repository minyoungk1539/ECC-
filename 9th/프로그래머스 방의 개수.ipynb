# %%
def solution(arrows):
    dx = [0, 1, 1, 1, 0, -1, -1, -1]
    dy = [1, 1, 0, -1, -1, -1, 0, 1]
    
    x, y = 0, 0
    visited_node = set()
    visited_edge = set()
    
    visited_node.add((x, y))
    answer = 0

# %% [markdown]
# 모르겠습니다..
